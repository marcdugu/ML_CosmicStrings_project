# %%
import CNN_test as CNN

# %%
#Make a ConsmicStrings_data object -> stores the data of the files in the specified folder
root_directory = '/Users/marlindedrent/Desktop/Computational/mock_data'
data = CNN.CosmicStrings_data(directory = root_directory, n=100)

# %%
#Test if the data was imported properly
print(data.len())
item, label = data.__getitem__(0, asPytorchTensor=False)
print(len(item))
print(item, label)
# Out:
# 200
# 65536
# [[ -25.85673645   38.45755142   54.91790366]
#  [  10.88242249   81.77942926    9.43832327]
#  [ 123.69520161   37.73739109  -70.14806691]
#  ...
#  [ -44.58726672  -37.54409139  -37.72943752]
#  [ 122.8462119    64.41065954  -44.79410692]
#  [ -69.16358043   26.00078759 -186.69575305]] 0

# %%
#Set the hyperparameters
frac_training = 0.7
frac_validation = 0.2
learning_rate = 0.001
n_epochs = 100

# %%
#Run the neural network
CNN.RunNeuralNetwork(data, frac_training, frac_validation, learning_rate, n_epochs)
# Out:
# 140 40 20
# Training Epochs: 100%|████████████████████████████████████████████| 100/100 [15:43<00:00,  9.43s/it]
# Evaluating on Test Data...
# Test Loss: 2.7713, Test Accuracy: 0.4000
