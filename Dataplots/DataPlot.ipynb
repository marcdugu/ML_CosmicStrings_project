# %%
import numpy as np
import os
from numpy.random import random
import DataPlot
from gwpy.timeseries import TimeSeries as ts

# %%
#Specify the path to the file
relative_folder = "../mockdata"
file_name = "background_wf3.npy"

file_path = os.path.join(relative_folder, file_name)
data = np.load(file_path)

# %%
#Plot the strain as a function of time
#DataPlot.overlap_plot(data, x=1, alpha=0.8)
#DataPlot.combined_plot(data, x=2,  alpha=0.8)
#DataPlot.individual_plots(data, x=3)

DataPlot.final_dataplot(5, data, 3, 0.05, normalized=False, plotname='background_final')
# Out:
# figure has been saved as background_final.png

# %%
#plot the spectogram
#gradientplot = DataPlot.gradient_plot(data, 2, "testplot", max_25=True, normalized=False)
