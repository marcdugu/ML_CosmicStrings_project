# %%
import numpy as np
import DataPlot

# %%
#Specify the path to the file
path_1 = '/Users/marlindedrent/Desktop/Computational/mock_data/Injections/Whitened/injection_wf5.npy'
path_2 = '/Users/marlindedrent/Desktop/Computational/mock_data/Background/Whitened/background_wf0.npy'
data_1 = np.load(path_1)
data_2 = np.load(path_2)

# %%
#Plot the strain as a function of time
DataPlot.combined_plot(data_2)

# %%
#Plot the frequency (y-axis) and energy (colorbar) as function of time
DataPlot.gradient_plot(data_2, cmap='inferno', x=2)
