# %%
import numpy as np
import os
from numpy.random import random
import DataPlot
from gwpy.timeseries import TimeSeries as ts

# %%
#Specify the path to the file
relative_folder = "../mockdata"
file_name = "injection_wf10.npy"

file_path = os.path.join(relative_folder, file_name)
data = np.load(file_path)
print("hello")

# %%
#Plot the strain as a function of time
#DataPlot.overlap_plot(data, alpha=0.8)

DataPlot.individual_plots(data)

# %%
#plot the spectogram
gradientplot = DataPlot.gradient_plot(data, 2, "testplot", max_25=False, normalized=False)
# Out:
# figure has been saved as testplot.png
# <Plot size 800x400 with 2 Axes>
