# %%
import numpy as np
import os
from numpy.random import random
import DataPlot
from gwpy.timeseries import TimeSeries as ts

# %%
#Specify the path to the file
relative_folder = "../mockdata"
file_name = "injection_wf10.npy"

file_path = os.path.join(relative_folder, file_name)
data = np.load(file_path)

# %%
#Plot the strain as a function of time
DataPlot.combined_plots_together(data)

DataPlot.individual_plots(data)

# %%
#plot the spectogram
gradientplot = DataPlot.gradient_plot(data, 6, "testplot", max_25=False, normalized=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #plot the spectogram
# ----> 2 gradientplot = DataPlot.gradient_plot(data, 6, "testplot", max_25=False, normalized=False)
#
# File ~/Documents/GitHub/ML_CosmicStrings/Plot_test/DataPlot.py:107, in gradient_plot(data, arm, plotname, cmap, max_25, normalized)
#      95 """
#      96 data[n.parray]: 4x65536 array -> column 0-2 are E1, E2 and E3, column 3 is time
#      97 arm[int]: select an arm (can be 1, 2 or 3)
#    (...)
#     104 Returns a plot of the frequency (y-axis) and energy (colorbar) as function of time
#     105 """
#     106 if arm not in (1, 2, 3):
# --> 107     raise ValueError(f"arm must be 1, 2, or 3, but got {arm}")
#     108 else:
#     109     arm = arm-1
#
# ValueError: arm must be 1, 2, or 3, but got 6
